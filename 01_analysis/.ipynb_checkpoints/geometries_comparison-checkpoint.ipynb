# %%
# %matplotlib inline
import geopandas as gpd
import pandas as pd
pd.set_option('display.max_columns', 100)
from geopandas import GeoDataFrame
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import mapclassify as mc
# import pysal

# %%
parcels = gpd.read_file("/Users/darebrawley/Google Drive/CourseWork/2019-2020/00_thesis/00_data/RAW/philadelphia/dor_property_parcels/DOR_Parcel.geojson")

# %%
parcels.head()
# Out:
#    OBJECTID RECSUB     BASEREG      MAPREG PARCEL  RECMAP    STCOD   HOUSE  \
# 0      2001         005N080178  005N080178   0178  005N08  87850.0   624.0
# 1      2002         006N090242  006N090242   0242  006N09  59520.0   934.0
# 2      2003         041S060225  041S060225   0225  041S06  21420.0  2439.0
# 3      2004         009N110233  009N110233   0233  009N11  62760.0  1224.0
# 4      2005         048S200008  048S200008   0008  048S20  43300.0  7800.0
#
#     SUF  UNIT  STEX  STDIR       STNAM        STDES STDESSUF ELEV_FLAG  \
# 0  None  None   NaN  North         3RD   ST, Street     None        No
# 1  None  None   NaN   None  NEW MARKET   ST, Street     None        No
# 2  None  None   NaN  South    CARLISLE   ST, Street     None        No
# 3  None  None   NaN   None   PALETHORP   ST, Street     None        No
# 4  None  None   NaN   None    HOLSTEIN  AVE, Avenue     None        No
#
#    TOPELEV  BOTELEV CONDOFLAG                              MATCHFLAG  \
# ...

# %%
parcels.plot()

# %%
res_C = gpd.read_file("/Users/darebrawley/Google Drive/CourseWork/2019-2020/00_thesis/00_data/PROCESSED/land_use/res_C.geojson")

# %%
res_C.plot()

# %%
res_C.head()
# Out:
#    OBJECTID C_DIG1   C_DIG1DESC C_DIG2          C_DIG2DESC C_DIG3  \
# 0      2001      1  Residential     12  Residential Medium    121
# 1      2002      1  Residential     12  Residential Medium    121
# 2      2003      1  Residential     12  Residential Medium    121
# 3      2004      1  Residential     12  Residential Medium    121
# 4      2005      1  Residential     12  Residential Medium    121
#
#              C_DIG3DESC  YEAR   Shape__Are  Shape__Len VACBLDG  \
# 0  Residential Rowhouse  2015  1683.997986  224.524100    None
# 1  Residential Rowhouse  2015  2959.593567  253.827456    None
# 2  Residential Rowhouse  2015  3071.876709  249.767972    None
# 3  Residential Rowhouse  2015  1672.240112  216.731026    None
# 4  Residential Rowhouse  2015  3398.521057  294.794364    None
#
#                                             geometry
# 0  POLYGON ((2674230.414 219482.604, 2674224.809 ...
# 1  POLYGON ((2674180.663 219406.187, 2674176.192 ...
# ...
