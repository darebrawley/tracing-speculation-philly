# %%
# %matplotlib inline
import geopandas as gpd
import pandas as pd
pd.set_option('display.max_columns', 100)
from geopandas import GeoDataFrame
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import mapclassify as mc
# import pysal

# %%
deeds = gpd.read_file("../00_data/PROCESSED/realestate_tax_transfers/rtt_investors_classified.geojson")
deeds.crs = {'init':'epsg:2272'}

# %%
deeds['count_field'] = 1
deeds['year'] = deeds['sort_year_x'].astype(str)
deeds.head()
# Out:
#   id C_DIG1   C_DIG1DESC C_DIG2          C_DIG2DESC C_DIG3  \
# 0  0      1  Residential     12  Residential Medium    121
# 1  1      1  Residential     11     Residential Low    112
# 2  2      1  Residential     12  Residential Medium    121
# 3  3      1  Residential     12  Residential Medium    121
# 4  4      1  Residential     11     Residential Low    111
#
#                  C_DIG3DESC  OBJECTID   Shape__Are  Shape__Len       VACBLDG  \
# 0      Residential Rowhouse   7744699   952.673950  165.045972  Fully Vacant
# 1  Residential SemiDetached   7744935  3395.618225  298.879760          None
# 2      Residential Rowhouse   7744943  1717.321350  237.627137          None
# 3      Residential Rowhouse   7744945  1555.363403  195.088770          None
# 4      Residential Detached   7744231  6734.606567  352.840272          None
#
#    YEAR  address_high  address_low address_low_frac address_low_suffix  \
# 0  2014           NaN       3083.0             None               None
# 1  2016           NaN       3631.0             None               None
# 2  2015           NaN       3430.0             None               None
# 3  2012           NaN       5809.0             None               None
# 4  2013           NaN       1403.0             None               None
#
#    adjusted_assessed_value  adjusted_cash_consideration  \
# 0                      NaN                      58900.0
# 1                      NaN                      92000.0
# 2                      NaN                     123000.0
# 3                      NaN                      93000.0
# 4                      NaN                      68500.0
#
#    adjusted_fair_market_value  adjusted_local_tax_amount  \
# 0                    30699.84                     1767.0
# 1                    63936.00                     2760.0
# 2                    43066.56                     3690.0
# 3                    45344.64                     2790.0
# 4                   305913.60                     2055.0
#
#    adjusted_other_consideration  adjusted_state_tax_amount  \
# 0                           NaN                      589.0
# 1                           NaN                      920.0
# 2                           NaN                     1230.0
# 3                           NaN                      930.0
# 4                           NaN                      685.0
#
#    adjusted_total_consideration  assessed_value  cash_consideration  \
# 0                       58900.0             NaN             58900.0
# 1                       92000.0             NaN             92000.0
# 2                      123000.0             NaN            123000.0
# 3                       93000.0             NaN             93000.0
# 4                       68500.0             NaN             68500.0
#
#    common_level_ratio condo_name discrepancy display_date_x display_date_y  \
# 0                 NaN       None          no     2004-04-02            NaT
# 1                 NaN       None          no     2000-05-25            NaT
# 2                 NaN       None          no     2004-05-28            NaT
# 3                 NaN       None          no     2004-05-28            NaT
# 4                 NaN       None          no     2004-05-12            NaT
#
#   document_date  document_id document_type              elapsed  elapsed_days  \
# 0    2004-04-02     50942296          DEED -9223372036854775808           NaN
# 1    2000-05-25     50092387          DEED -9223372036854775808           NaN
# 2    2004-05-28     50942514          DEED -9223372036854775808           NaN
# 3    2004-05-28     50942516          DEED -9223372036854775808           NaN
# 4    2004-05-12     50941882          DEED -9223372036854775808           NaN
#
#    fair_market_value       grantees_x_x grantees_x_y  grantees_y  \
# 0           30699.84    IRWIN LEIGHANNE         None       False
# 1           63936.00  FALLEN PAUL J III         None       False
# 2           43066.56      RUTA JOSEPH M         None       False
# 3           45344.64       DUFFIE JAMIE         None       False
# 4          305913.60            NVR INC         None        True
#
#                                           grantors_x grantors_y  index_right  \
# 0              MCCAFFERTY MARIE E; TUCKER MARGARET T       None       228137
# 1  TAYLOR COLERIDGE; TAYLOR ROBERT TR; TAYLOR RON...       None       450144
# 2                        ROWLAND JAMES; ROWLAND JOAN       None       396862
# 3                                         LAVIN BETH       None       394648
# 4                   CHAMPION DEVELOPMENT CORPORATION       None       398198
#
#    inv  investor_all        lat legal_remarks        lng  local_tax_amount  \
# 0    0           0.0  39.987205          None -75.109769            1767.0
# 1    0           0.0  40.074151          None -74.997365            2760.0
# 2    0           0.0  40.038977          None -75.041471            3690.0
# 3    0           0.0  40.028446          None -75.078006            2790.0
# 4    1           1.0  40.070579     SUB OF 33 -75.063039            2055.0
#
#    local_tax_percent matched_regmap  multi_invest  occ  opa_account_num  \
# 0              100.0     022N240033           NaN    1      251496000.0
# 1              100.0     084N180294           NaN    1      661087900.0
# 2              100.0     137N180119           NaN    1      642110500.0
# 3              100.0     139N020114           NaN    1      621440200.0
# 4              100.0     154N130125           NaN    0      562065112.0
#
#    other_consideration  owner_occup  property_count receipt_date receipt_num  \
# 0                  NaN            1             1.0   2004-06-07        None
# 1                  0.0            1             1.0   2000-06-07        None
# 2                  NaN            1             1.0   2004-06-08        None
# 3                  NaN            1             1.0   2004-06-08        None
# 4                  NaN            0             1.0   2004-06-07        None
#
#   recording_date  reg_map_id  sort_year_x  sort_year_y  state_tax_amount  \
# 0     2004-06-07  022N240033         2004          NaN             589.0
# 1     2000-06-07  084N180294         2000          NaN             920.0
# 2     2004-06-08  137N180119         2004          NaN            1230.0
# 3     2004-06-08  139N020114         2004          NaN             930.0
# 4     2004-06-07  154N130125         2004          NaN             685.0
#
#    state_tax_percent     street_address_x street_address_y street_name  \
# 0              100.0      3083 MEMPHIS ST             None     MEMPHIS
# 1              100.0       3631 AVALON ST             None      AVALON
# 2              100.0       3430 ALDINE ST             None      ALDINE
# 3              100.0        5809 AKRON ST             None       AKRON
# 4              100.0  1403 ROSE PETAL WAY             None  ROSE PETAL
#
#   street_postdir street_predir street_suffix  total_consideration unit_num  \
# 0           None          None            ST              58900.0     None
# 1           None          None            ST              92000.0     None
# 2           None          None            ST             123000.0     None
# 3           None          None            ST              93000.0     None
# 4           None          None           WAY              68500.0     None
#
#    ward  zip_code                        geometry  count_field  year
# 0  25.0   19134.0  POINT (2708217.048 249254.954)            1  2004
# 1  66.0   19114.0  POINT (2738712.165 281874.230)            1  2000
# 2  64.0   19136.0  POINT (2726767.783 268685.145)            1  2004
# 3  62.0   19149.0  POINT (2716659.025 264539.033)            1  2004
# 4  56.0   19111.0  POINT (2720381.369 280007.648)            1  2004

# %%
deeds
# Out:
#             id C_DIG1   C_DIG1DESC C_DIG2          C_DIG2DESC C_DIG3  \
# 0            0      1  Residential     12  Residential Medium    121
# 1            1      1  Residential     11     Residential Low    112
# 2            2      1  Residential     12  Residential Medium    121
# 3            3      1  Residential     12  Residential Medium    121
# 4            4      1  Residential     11     Residential Low    111
# ...        ...    ...          ...    ...                 ...    ...
# 458924  458924      1  Residential     12  Residential Medium    121
# 458925  458925      1  Residential     12  Residential Medium    121
# 458926  458926      1  Residential     12  Residential Medium    121
# 458927  458927      1  Residential     12  Residential Medium    121
# 458928  458928      1  Residential     12  Residential Medium    121
#
#                       C_DIG3DESC  OBJECTID   Shape__Are  Shape__Len  \
# 0           Residential Rowhouse   7744699   952.673950  165.045972
# 1       Residential SemiDetached   7744935  3395.618225  298.879760
# 2           Residential Rowhouse   7744943  1717.321350  237.627137
# 3           Residential Rowhouse   7744945  1555.363403  195.088770
# 4           Residential Detached   7744231  6734.606567  352.840272
# ...                          ...       ...          ...         ...
# 458924      Residential Rowhouse  11699368  1980.665710  258.794477
# 458925      Residential Rowhouse  11699372   817.876770  126.727964
# 458926      Residential Rowhouse  11699585  2082.615234  243.275286
# 458927      Residential Rowhouse  11699591   638.790527  118.416389
# 458928      Residential Rowhouse  11699592  1187.822571  166.187482
#
#              VACBLDG  YEAR  address_high  address_low address_low_frac  \
# 0       Fully Vacant  2014           NaN       3083.0             None
# 1               None  2016           NaN       3631.0             None
# 2               None  2015           NaN       3430.0             None
# 3               None  2012           NaN       5809.0             None
# 4               None  2013           NaN       1403.0             None
# ...              ...   ...           ...          ...              ...
# 458924          None  2016           NaN       5838.0             None
# 458925          None  2012           NaN        540.0             None
# 458926          None  2014           NaN       2716.0             None
# 458927          None  2016           NaN       1019.0             None
# 458928          None  2012           NaN       1531.0             None
#
#        address_low_suffix  adjusted_assessed_value  \
# 0                    None                      NaN
# 1                    None                      NaN
# 2                    None                      NaN
# 3                    None                      NaN
# 4                    None                      NaN
# ...                   ...                      ...
# 458924               None                  97400.0
# 458925               None                 470300.0
# 458926               None                 347200.0
# 458927               None                  41200.0
# 458928               None                 512300.0
#
#         adjusted_cash_consideration  adjusted_fair_market_value  \
# 0                           58900.0                    30699.84
# 1                           92000.0                    63936.00
# 2                          123000.0                    43066.56
# 3                           93000.0                    45344.64
# 4                           68500.0                   305913.60
# ...                             ...                         ...
# 458924                      85000.0                    98374.00
# 458925                     680000.0                   475003.00
# 458926                     350000.0                   350672.00
# 458927                          1.0                    41612.00
# 458928                     512500.0                   517423.00
#
#         adjusted_local_tax_amount  adjusted_other_consideration  \
# 0                         1767.00                           NaN
# 1                         2760.00                           NaN
# 2                         3690.00                           NaN
# 3                         2790.00                           NaN
# 4                         2055.00                           NaN
# ...                           ...                           ...
# 458924                    2786.30                           NaN
# 458925                   22290.40                           NaN
# 458926                   11473.00                           NaN
# 458927                    1364.04                           NaN
# 458928                   16799.75                           NaN
#
#         adjusted_state_tax_amount  adjusted_total_consideration  \
# 0                          589.00                       58900.0
# 1                          920.00                       92000.0
# 2                         1230.00                      123000.0
# 3                          930.00                       93000.0
# 4                          685.00                       68500.0
# ...                           ...                           ...
# 458924                     850.00                       85000.0
# 458925                    6800.00                      680000.0
# 458926                    3500.00                      350000.0
# 458927                     416.12                           1.0
# 458928                    5125.00                      512500.0
#
#         assessed_value  cash_consideration  common_level_ratio  \
# 0                  NaN             58900.0                 NaN
# 1                  NaN             92000.0                 NaN
# 2                  NaN            123000.0                 NaN
# 3                  NaN             93000.0                 NaN
# 4                  NaN             68500.0                 NaN
# ...                ...                 ...                 ...
# 458924         97400.0             85000.0                1.01
# 458925        470300.0            680000.0                1.01
# 458926        347200.0            350000.0                1.01
# 458927         41200.0                 1.0                1.01
# 458928        512300.0            512500.0                1.01
#
#                 condo_name discrepancy display_date_x display_date_y  \
# 0                     None          no     2004-04-02            NaT
# 1                     None          no     2000-05-25            NaT
# 2                     None          no     2004-05-28            NaT
# 3                     None          no     2004-05-28            NaT
# 4                     None          no     2004-05-12            NaT
# ...                    ...         ...            ...            ...
# 458924                None          no     2019-07-25            NaT
# 458925                None         yes     2019-07-23            NaT
# 458926                None          no     2019-07-15     2019-07-15
# 458927                None          no     2019-05-23            NaT
# 458928  1531 BAINBRIDGE ST          no     2019-07-09            NaT
#
#        document_date  document_id document_type              elapsed  \
# 0         2004-04-02     50942296          DEED -9223372036854775808
# 1         2000-05-25     50092387          DEED -9223372036854775808
# 2         2004-05-28     50942514          DEED -9223372036854775808
# 3         2004-05-28     50942516          DEED -9223372036854775808
# 4         2004-05-12     50941882          DEED -9223372036854775808
# ...              ...          ...           ...                  ...
# 458924    2019-07-25     53544912          DEED -9223372036854775808
# 458925    2019-07-23     53544916          DEED -9223372036854775808
# 458926    2019-07-15     53545089          DEED     4147200000000000
# 458927    2019-05-23     53545095          DEED -9223372036854775808
# 458928    2019-07-09     53545096          DEED -9223372036854775808
#
#         elapsed_days  fair_market_value  \
# 0                NaN           30699.84
# 1                NaN           63936.00
# 2                NaN           43066.56
# 3                NaN           45344.64
# 4                NaN          305913.60
# ...              ...                ...
# 458924           NaN           98374.00
# 458925           NaN          475003.00
# 458926          48.0          350672.00
# 458927           NaN           41612.00
# 458928           NaN          517423.00
#
#                                      grantees_x_x          grantees_x_y  \
# 0                                 IRWIN LEIGHANNE                  None
# 1                               FALLEN PAUL J III                  None
# 2                                   RUTA JOSEPH M                  None
# 3                                    DUFFIE JAMIE                  None
# 4                                         NVR INC                  None
# ...                                           ...                   ...
# 458924  MONTINAT GUERLINE RENOIS; RENOIS MIDELENS                  None
# 458925                             LEEDS LUANNE C                  None
# 458926                       LIU DAVID; LIU HEIDI  LIU DAVID; LIU HEIDI
# 458927                                HOWE MARCIA                  None
# 458928             HARTMANN JULIA; SCHWARZ MARLON                  None
#
#         grantees_y                                         grantors_x  \
# 0            False              MCCAFFERTY MARIE E; TUCKER MARGARET T
# 1            False  TAYLOR COLERIDGE; TAYLOR ROBERT TR; TAYLOR RON...
# 2            False                        ROWLAND JAMES; ROWLAND JOAN
# 3            False                                         LAVIN BETH
# 4             True                   CHAMPION DEVELOPMENT CORPORATION
# ...            ...                                                ...
# 458924       False                                          LO T NONG
# 458925       False                                 PODAGROSI JAMES JR
# 458926       False             DIBERARDINIS GABRIELE; MURAWSKI ALISON
# 458927       False  BROGAN SHANNON; DITTMAR JOANN; DITTMAR WILLIAM...
# 458928       False                             HUNTER INVESTMENTS LLC
#
#                                     grantors_y  index_right  inv  \
# 0                                         None       228137    0
# 1                                         None       450144    0
# 2                                         None       396862    0
# 3                                         None       394648    0
# 4                                         None       398198    1
# ...                                        ...          ...  ...
# 458924                                    None       357406    0
# 458925                                    None        72774    0
# 458926  DIBERARDINIS GABRIELE; MURAWSKI ALISON       220514    0
# 458927                                    None       205794    0
# 458928                                    None       140346    0
#
#         investor_all        lat legal_remarks        lng  local_tax_amount  \
# 0                0.0  39.987205          None -75.109769           1767.00
# 1                0.0  40.074151          None -74.997365           2760.00
# 2                0.0  40.038977          None -75.041471           3690.00
# 3                0.0  40.028446          None -75.078006           2790.00
# 4                1.0  40.070579     SUB OF 33 -75.063039           2055.00
# ...              ...        ...           ...        ...               ...
# 458924           0.0  40.040618          None -75.129929           2786.30
# 458925           0.0  39.937924          None -75.152941          22290.40
# 458926           1.0  39.978159          None -75.113535          11473.00
# 458927           0.0  39.996732          None -75.147557           1364.04
# 458928           0.0  39.943279    SUB OF 374 -75.168421          16799.75
#
#         local_tax_percent matched_regmap  multi_invest  occ  opa_account_num  \
# 0                   100.0     022N240033           NaN    1      251496000.0
# 1                   100.0     084N180294           NaN    1      661087900.0
# 2                   100.0     137N180119           NaN    1      642110500.0
# 3                   100.0     139N020114           NaN    1      621440200.0
# 4                   100.0     154N130125           NaN    0      562065112.0
# ...                   ...            ...           ...  ...              ...
# 458924              100.0     135N090023           NaN    1      612326900.0
# 458925              100.0     005S190192           NaN    1       22078500.0
# 458926              100.0     020N210181           1.0    1      312179515.0
# 458927              100.0     036N170111           NaN    1      372394600.0
# 458928              100.0     005S050374           NaN    1      888303824.0
#
#         other_consideration  owner_occup  property_count receipt_date  \
# 0                       NaN            1             1.0   2004-06-07
# 1                       0.0            1             1.0   2000-06-07
# 2                       NaN            1             1.0   2004-06-08
# 3                       NaN            1             1.0   2004-06-08
# 4                       NaN            0             1.0   2004-06-07
# ...                     ...          ...             ...          ...
# 458924                  0.0            1             1.0   2019-07-31
# 458925                  0.0            1             1.0   2019-07-31
# 458926                  0.0            0             1.0   2019-07-31
# 458927                  0.0            1             1.0   2019-07-31
# 458928                  0.0            1             1.0   2019-07-31
#
#        receipt_num recording_date  reg_map_id  sort_year_x  sort_year_y  \
# 0             None     2004-06-07  022N240033         2004          NaN
# 1             None     2000-06-07  084N180294         2000          NaN
# 2             None     2004-06-08  137N180119         2004          NaN
# 3             None     2004-06-08  139N020114         2004          NaN
# 4             None     2004-06-07  154N130125         2004          NaN
# ...            ...            ...         ...          ...          ...
# 458924    19-74864     2019-07-31  135N090023         2019          NaN
# 458925    19-74867     2019-07-31  005S190255         2019          NaN
# 458926    19-75013     2019-07-31  020N210181         2019       2019.0
# 458927    19-75019     2019-07-31  036N170111         2019          NaN
# 458928    19-75020     2019-07-31  005S050440         2019          NaN
#
#         state_tax_amount  state_tax_percent           street_address_x  \
# 0                 589.00              100.0            3083 MEMPHIS ST
# 1                 920.00              100.0             3631 AVALON ST
# 2                1230.00              100.0             3430 ALDINE ST
# 3                 930.00              100.0              5809 AKRON ST
# 4                 685.00              100.0        1403 ROSE PETAL WAY
# ...                  ...                ...                        ...
# 458924            850.00              100.0              5838 N 5TH ST
# 458925           6800.00              100.0               540 QUEEN ST
# 458926           3500.00              100.0             2716 TILTON ST
# 458927            416.12              100.0         1019 W MONMOUTH ST
# 458928           5125.00              100.0  1531 BAINBRIDGE ST UNIT B
#
#        street_address_y street_name street_postdir street_predir  \
# 0                  None     MEMPHIS           None          None
# 1                  None      AVALON           None          None
# 2                  None      ALDINE           None          None
# 3                  None       AKRON           None          None
# 4                  None  ROSE PETAL           None          None
# ...                 ...         ...            ...           ...
# 458924             None         5TH           None             N
# 458925             None       QUEEN           None          None
# 458926   2716 TILTON ST      TILTON           None          None
# 458927             None    MONMOUTH           None             W
# 458928             None  BAINBRIDGE           None          None
#
#        street_suffix  total_consideration unit_num  ward  zip_code  \
# 0                 ST              58900.0     None  25.0   19134.0
# 1                 ST              92000.0     None  66.0   19114.0
# 2                 ST             123000.0     None  64.0   19136.0
# 3                 ST              93000.0     None  62.0   19149.0
# 4                WAY              68500.0     None  56.0   19111.0
# ...              ...                  ...      ...   ...       ...
# 458924            ST              85000.0     None  61.0   19120.0
# 458925            ST             680000.0     None   2.0   19147.0
# 458926            ST             350000.0     None  31.0   19134.0
# 458927            ST                  1.0     None  37.0   19133.0
# 458928            ST             512500.0        B  30.0   19146.0
#
#                               geometry  count_field  year
# 0       POINT (2708217.048 249254.954)            1  2004
# 1       POINT (2738712.165 281874.230)            1  2000
# 2       POINT (2726767.783 268685.145)            1  2004
# 3       POINT (2716659.025 264539.033)            1  2004
# 4       POINT (2720381.369 280007.648)            1  2004
# ...                                ...          ...   ...
# 458924  POINT (2701993.159 268535.500)            1  2019
# 458925  POINT (2696652.698 230951.820)            1  2019
# 458926  POINT (2707260.626 245929.613)            1  2019
# 458927  POINT (2697530.574 252409.733)            1  2019
# 458928  POINT (2692256.944 232774.579)            1  2019
#
# [458929 rows x 77 columns]

# %%
# grouping to be able to plot

total = deeds.groupby('year').agg({'count_field':'sum','inv':'sum','investor_all':'sum','occ':'sum'})
total['inv_nonLLC'] = total['investor_all']-total['inv']
total['inv_per'] = (total['investor_all']/total['count_field'])
total['inv_per_nonLLC'] = (total['inv_nonLLC']/total['count_field'])
total['inv_per_LLC'] = (total['inv']/total['count_field'])

# %%
total
# Out:
#       count_field   inv  investor_all    occ  inv_nonLLC   inv_per  \
# year
# 2000        23493  1853        6401.0  21640      4548.0  0.272464
# 2001        24357  2151        7494.0  22206      5343.0  0.307673
# 2002        25873  2457        8499.0  23416      6042.0  0.328489
# 2003        27789  3156        9531.0  24633      6375.0  0.342977
# 2004        31703  3514       11302.0  28189      7788.0  0.356496
# 2005        34731  4373       13032.0  30358      8659.0  0.375227
# 2006        31560  4020       10820.0  27540      6800.0  0.342839
# 2007        26826  3846        8851.0  22980      5005.0  0.329941
# 2008        20017  3172        6720.0  16845      3548.0  0.335715
# 2009        17666  2752        5569.0  14914      2817.0  0.315238
# 2010        17159  3199        6004.0  13960      2805.0  0.349904
# 2011        15200  2858        5495.0  12342      2637.0  0.361513
# 2012        16608  3485        6267.0  13123      2782.0  0.377348
# 2013        18383  3728        6754.0  14655      3026.0  0.367405
# 2014        18332  3864        6750.0  14468      2886.0  0.368209
# 2015        21055  4961        8012.0  16094      3051.0  0.380527
# 2016        24040  6016        9259.0  18024      3243.0  0.385150
# 2017        25547  6864       10253.0  18683      3389.0  0.401339
# 2018        25568  7067       10049.0  18501      2982.0  0.393030
# 2019        13022  3640        4974.0   9382      1334.0  0.381969
#
#       inv_per_nonLLC  inv_per_LLC
# year
# 2000        0.193590     0.078875
# 2001        0.219362     0.088311
# 2002        0.233525     0.094964
# 2003        0.229407     0.113570
# 2004        0.245655     0.110841
# 2005        0.249316     0.125911
# 2006        0.215463     0.127376
# 2007        0.186573     0.143368
# 2008        0.177249     0.158465
# 2009        0.159459     0.155779
# 2010        0.163471     0.186433
# 2011        0.173487     0.188026
# 2012        0.167510     0.209839
# 2013        0.164609     0.202796
# 2014        0.157430     0.210779
# 2015        0.144906     0.235621
# 2016        0.134900     0.250250
# 2017        0.132657     0.268681
# 2018        0.116630     0.276400
# 2019        0.102442     0.279527

# %%
f, (ax1) = plt.subplots(1,1,figsize=(15, 10))
# sns.set(style="white" )
sns.lineplot(data=total['inv','investor_all','occ'], ax=ax1)

# %% [markdown]
# ## 1. total purchases

# %%
total_bar = total.reset_index()
f, (ax1) = plt.subplots(1,1,figsize=(10, 10))
sns.set(style="white")

plt.bar(data=total_bar,x='year', 
            height='count_field',label='total purchases', color = 'grey',width=.3)
plt.bar(data=total_bar, x='year',
            height='investor_all',label='investor purchases', color = '#FF7C00', width=.3)
plt.bar(data=total_bar, x='year',
            height='inv',label='investor purchases', color = '#FFE1BF', width=.3)
plt.savefig('../05_drawings/time_series/summary_total_purchases.svg')

# %%
total_bar = total.reset_index()
f, (ax1) = plt.subplots(1,1,figsize=(40, 10))
sns.set(style="white")

plt.plot(total_bar['year'],total_bar['count_field'], marker='o', color = 'black')
plt.plot(total_bar['year'],total_bar['investor_all'], marker='o', color = 'black')
plt.plot(total_bar['year'],total_bar['inv'], marker='o', color = 'black')

# plt.bar(data=total_bar, x='year',
#             height='investor_all',label='investor purchases', color = 'black', width=.3)
# plt.bar(data=total_bar, x='year',
#             height='inv',label='investor purchases', color = 'pink', width=.3)
# plt.savefig('../05_drawings/time_series/summary_total_purchases.svg')

# %%
total_bar = total.reset_index()
f, (ax1) = plt.subplots(1,1,figsize=(40, 10))
sns.set(style="white")

# plt.plot(total_bar['year'],total_bar['count_field'], marker='o', color = 'black')
plt.plot(total_bar['year'],total_bar['inv_per'], marker='o', color = 'black')
plt.plot(total_bar['year'],total_bar['inv_per_LLC'], marker='o', color = 'black')

# plt.bar(data=total_bar, x='year',
#             height='investor_all',label='investor purchases', color = 'black', width=.3)
# plt.bar(data=total_bar, x='year',
#             height='inv',label='investor purchases', color = 'pink', width=.3)
# plt.savefig('../05_drawings/time_series/summary_total_purchases.svg')

# %% [markdown]
# ## 2. percent likely investor purchases

# %%
total_bar = total.reset_index()
f, (ax1) = plt.subplots(1,1,figsize=(10, 10))
# sns.set(style="white")

plt.bar(data=total_bar,x='year', 
            height=.5,label='total purchases', color = 'white')
plt.bar(data=total_bar, x='year',
            height='inv_per',label='investor purchases', color = '#FF7C00',width=.3)
plt.bar(data=total_bar, x='year',
            height='inv_per_LLC',label='investor purchases', color = '#FFE1BF',width=.3)

# plt.plot(total_bar['year'],total_bar['inv_per_LLC'], marker='s',color="white")

# plt.bar(data=total_bar, x='year',
#             height='inv_per_nonLLC',label='investor purchases', color = 'pink',width=.3)


plt.savefig('../05_drawings/time_series/summary_percent_investor.svg')

# %% [markdown]
# ## comparing density of likely investor purchases

# %%
grouped_ct_10_18 = gpd.read_file("../00_data/PROCESSED/grouped_ct_deeds10_18.geojson")
grouped_ct_00_10 = gpd.read_file("../00_data/PROCESSED/grouped_ct_deeds00_10.geojson")

# %%
grouped_ct_10_18 = grouped_ct_10_18.drop(['GEOID10','geometry','res_parcel_num'],axis=1)

# %%
grouped_ct_00_10 = grouped_ct_00_10.drop(['STFID','geometry','res_parcel_num'],axis=1)

# %%
mean1018= grouped_ct_10_18.mean()

# %%
sd1018 = grouped_ct_10_18.std()

# %%
mean1018 = mean1018.append(grouped_ct_00_10.mean())
sd1018 = sd1018.append(grouped_ct_00_10.std())

# %%
stats = pd.concat([mean1018,sd1018],axis=1)
names = ['mean','sd']
stats.columns = names
stats = stats.reset_index()
stats['year'] = stats['index'].str[-4:]
stats['cat'] = stats['index'].str[:-4]

# %%
stats_shaped = stats.pivot(index='year',columns='cat',values=['mean','sd'])

# %%
stats_shaped.columns = ['_'.join((col[1], col[0])) for col in stats_shaped.columns]

# %%
stats_line = stats_shaped.reset_index()

# %%
stats_line = stats_line.astype({'year':'int64'})

# %% [markdown]
# ## 3a. density of likely investor purchases - table

# %%
stats_line
# Out:
#     year  count_field_mean  investor_all_mean  owner_occup_mean  \
# 0   2000         61.661417          16.800525         44.860892
# 1   2001         63.929134          19.669291         44.259843
# 2   2002         67.908136          22.307087         45.601050
# 3   2003         72.937008          25.015748         47.921260
# 4   2004         83.209974          29.664042         53.545932
# 5   2005         91.157480          34.204724         56.952756
# 6   2006         82.834646          28.398950         54.435696
# 7   2007         70.409449          23.230971         47.178478
# 8   2008         52.538058          17.637795         34.900262
# 9   2009         46.367454          14.616798         31.750656
# 10  2010         44.684896          15.635417         29.049479
# 11  2011         39.583333          14.309896         25.273438
# 12  2012         43.250000          16.320312         26.929688
# 13  2013         47.872396          17.588542         30.283854
# 14  2014         47.739583          17.578125         30.161458
# 15  2015         54.830729          20.864583         33.966146
# 16  2016         62.604167          24.111979         38.492188
# 17  2017         66.528646          26.700521         39.828125
# 18  2018         66.583333          26.169271         40.414062
# 19  2019         33.911458          12.953125         20.958333
#
#     per_inv__mean  per_occ__mean  count_field_sd  investor_all_sd  \
# 0        0.013168       0.034050       55.609241        17.656283
# 1        0.014943       0.032877       58.112212        22.339977
# 2        0.017437       0.033944       60.966121        24.109022
# 3        0.018422       0.035307       65.543326        26.672670
# 4        0.021763       0.039517       75.327656        33.016463
# 5        0.024864       0.042666       78.844560        36.631092
# 6        0.021489       0.040340       67.178407        30.537869
# 7        0.018222       0.036386       56.360497        25.716556
# 8        0.013939       0.026523       41.171614        19.462110
# 9        0.011518       0.024925       36.606462        14.929135
# 10       0.013026       0.023793       30.845817        16.393573
# 11       0.012212       0.020698       26.969925        13.050026
# 12       0.013590       0.021990       28.988518        13.999776
# 13       0.014641       0.025322       33.389495        15.192498
# 14       0.014055       0.024244       34.497737        16.282562
# 15       0.015715       0.027606       39.322327        19.431406
# 16       0.018566       0.030544       43.062703        21.832031
# 17       0.021099       0.031762       45.682286        23.470250
# 18       0.020737       0.031294       45.427742        23.291097
# 19            NaN            NaN       23.122502        11.617170
#
#     owner_occup_sd  per_inv__sd  per_occ__sd
# 0        42.589893     0.011677     0.029463
# 1        41.890687     0.013574     0.021221
# 2        43.125196     0.014641     0.022751
# 3        46.338731     0.013829     0.023409
# 4        50.682511     0.018530     0.024118
# 5        51.196504     0.020441     0.025825
# 6        45.335813     0.018207     0.021885
# 7        38.596764     0.019614     0.025647
# 8        28.266505     0.014484     0.015429
# 9        27.295812     0.013206     0.025928
# 10       20.120139     0.018492     0.016181
# 11       17.993783     0.015571     0.013926
# 12       19.986882     0.011651     0.014481
# 13       22.808320     0.013655     0.018027
# 14       22.646909     0.010566     0.015280
# 15       25.112414     0.011014     0.016025
# 16       28.701852     0.012496     0.018735
# 17       29.849958     0.015604     0.018941
# 18       30.720723     0.018532     0.017659
# 19       15.787205          NaN          NaN

# %% [markdown]
# ## 3a. density of likely investor purchases - chart

# %%
f, (ax1,ax2) = plt.subplots(2,1,figsize=(10, 10),sharey=True)
# sns.set(style="white")
plt.title("Density of deeds in Philadelphia by census tract")
# sns.boxplot(data=stats_line,x='year', 
#             y='count_field_mean', color = 'grey')
ax1.errorbar(data=stats_line,x='year', 
            y='per_inv__mean', yerr= 'per_inv__sd', color = 'black',linestyle='none', marker='*')
ax2.errorbar(data=stats_line,x='year', 
            y='per_occ__mean', yerr='per_occ__sd', color = 'b',linestyle='none', marker='^')
ax1.set_title("likely investor purchases normalized by tract")
ax2.set_title("likely owner occupant purchases normalized by tract")
# sns.scatterplot(data=stats_line,x='year', 
#             y='per_occ__sd', color = 'lightblue',)
# sns.scatterplot(data=stats_line,x='year', 
#             y='per_inv__sd', color = 'magenta',)
# sns.barplot(data=total_bar, x='year',
#             y='investor_all',label='investor purchases', color = 'black')
plt.savefig('02_outputs/complete_drafts/summary_density_purchasers_tract.svg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d9f5db680fe6> in <module>
# ----> 1 f, (ax1,ax2) = plt.subplots(2,1,figsize=(10, 10),sharey=True)
#       2 # sns.set(style="white")
#       3 plt.title("Density of deeds in Philadelphia by census tract")
#       4 # sns.boxplot(data=stats_line,x='year',
#       5 #             y='count_field_mean', color = 'grey')
#
# NameError: name 'plt' is not defined
