# %%
import geopandas as gpd
import pandas as pd
pd.set_option('display.max_columns', 50)
from shapely.geometry import Point, LineString
from geopandas import GeoDataFrame
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
import seaborn as sns

# %%
landuse = gpd.read_file("/Users/darebrawley/Google Drive/CourseWork/2019-2020/00_thesis/00_data/RAW/philadelphia/land_use/Land_Use_2019/Land_Use.shp")

# %%
landuse.head()
# Out:
#    OBJECTID C_DIG1   C_DIG1DESC C_DIG2          C_DIG2DESC C_DIG3  \
# 0      2001      1  Residential     12  Residential Medium    121
# 1      2002      1  Residential     12  Residential Medium    121
# 2      2003      1  Residential     12  Residential Medium    121
# 3      2004      1  Residential     12  Residential Medium    121
# 4      2005      1  Residential     12  Residential Medium    121
#
#              C_DIG3DESC VACBLDG  YEAR   Shape__Are  Shape__Len  \
# 0  Residential Rowhouse    None  2015  1683.997986  224.524100
# 1  Residential Rowhouse    None  2015  2959.593567  253.827456
# 2  Residential Rowhouse    None  2015  3071.876709  249.767972
# 3  Residential Rowhouse    None  2015  1672.240112  216.731026
# 4  Residential Rowhouse    None  2015  3398.521057  294.794364
#
#                                             geometry
# 0  POLYGON ((-75.2340347725966 39.9082342884392, ...
# 1  POLYGON ((-75.2342198012356 39.9080284896552, ...
# ...

# %%
landuse.shape
# Out:
# (560104, 12)

# %%
landuse.plot()

# %%
landuse.sort_values(by="YEAR")
# Out:
#         OBJECTID C_DIG1       C_DIG1DESC C_DIG2                    C_DIG2DESC  \
# 188978    188979      7  Park/Open Space     71               Park/Open Space
# 275914    276915      1      Residential     12            Residential Medium
# 275915    276916      1      Residential     12            Residential Medium
# 275916    276917      1      Residential     12            Residential Medium
# 275917    276918      1      Residential     12            Residential Medium
# 275918    276919      1      Residential     12            Residential Medium
# 275919    276920      1      Residential     12            Residential Medium
# 275920    276921      1      Residential     12            Residential Medium
# 275921    276922      1      Residential     12            Residential Medium
# 290869    290870      1      Residential     12            Residential Medium
# 290868    290869      1      Residential     12            Residential Medium
# ...

# %%
landuse['C_DIG3DESC'].unique()
# Out:
# array(['Residential Rowhouse', 'Vacant Parcels',
#        'Apt House or Condo LT 5 units incl Duplex or Quad LT 3stry',
#        'Park Open Space', 'Warehousing and Distribution',
#        'Other production distribution repair maintenance',
#        'Transportation Truck Bus Taxi', 'Utilities', 'Commercial Auto',
#        '529', 'Commercial Office',
#        'Manufacturing wood paper printing petroleum chemicals plastics rubber',
#        'Construction', 'Transportation Parking', 'Other Industrial',
#        'Other Civic', 'Water', 'Transportation Marine',
#        'Transportation Rail ROW Yards Stations',
#        'Transportation Parking Commercial Mix', 'Public Safety',
#        'Commercial Store', 'Rowhouse Store or Office with Apts',
#        'Residential SemiDetached', 'Residential Detached', 'Other RLD',
#        'Other RMD', 'Commercial Service',
#        'Residential Rowhouse Converted to Apts LT 3st LT 5 units',
# ...

# %%
land

# %%
year_not_none = landuse.loc[(landuse["YEAR"] != None)]

# %%
trans = landuse.loc[landuse["C_DIG3"] == '511']

# %%
# street network shapefile
trans.plot()

# %%
# Out:
#         OBJECTID C_DIG1      C_DIG1DESC C_DIG2      C_DIG2DESC C_DIG3  \
# 120         2121      5  Transportation     51  Transportation    513
# 131         2132      5  Transportation     51  Transportation    513
# 201         2202      5  Transportation     52              52    529
# 209         2210      5  Transportation     51  Transportation    514
# 211         2212      5  Transportation     51  Transportation    514
# 221         2222      5  Transportation     52              52    529
# 224         2225      5  Transportation     51  Transportation    516
# 225         2226      5  Transportation     52              52    529
# 226         2227      5  Transportation     51  Transportation    512
# 227         2228      5  Transportation     51  Transportation    515
# 229         2230      5  Transportation     52              52    529
# 231         2232      5  Transportation     52              52    529
# ...

# %%
residential = landuse.loc[(landuse['C_DIG1'] =='1') | (landuse['C_DIG2'] =='23')]

# %%
residential.head()
# Out:
#    OBJECTID C_DIG1   C_DIG1DESC C_DIG2          C_DIG2DESC C_DIG3  \
# 0      2001      1  Residential     12  Residential Medium    121
# 1      2002      1  Residential     12  Residential Medium    121
# 2      2003      1  Residential     12  Residential Medium    121
# 3      2004      1  Residential     12  Residential Medium    121
# 4      2005      1  Residential     12  Residential Medium    121
#
#              C_DIG3DESC VACBLDG  YEAR   Shape__Are  Shape__Len  \
# 0  Residential Rowhouse    None  2015  1683.997986  224.524100
# 1  Residential Rowhouse    None  2015  2959.593567  253.827456
# 2  Residential Rowhouse    None  2015  3071.876709  249.767972
# 3  Residential Rowhouse    None  2015  1672.240112  216.731026
# 4  Residential Rowhouse    None  2015  3398.521057  294.794364
#
#                                             geometry
# 0  POLYGON ((-75.2340347725966 39.9082342884392, ...
# 1  POLYGON ((-75.2342198012356 39.9080284896552, ...
# ...

# %%
residential.plot(figsize=(20,20))

# %%
row_house = landuse.loc[(landuse['C_DIG3'] == '121')]

# %%
row_house.plot(figsize=(20,20))
