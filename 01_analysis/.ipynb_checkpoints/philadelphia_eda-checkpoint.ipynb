# %%
import csv
import numpy
import pandas as pd
pd.set_option('display.max_columns', 50)
import geopandas as gpd

# %%
phil = pd.read_csv("../00_data/RAW/philadelphia/realestate_tax_transfers/RTT_SUMMARY.csv")
# Out:
# /Users/darebrawley/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (26,34,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
phil['document_type'].unique()
# Out:
# array(['SATISFACTION', 'RELEASE OF MORTGAGE', 'ASSIGNMENT OF MORTGAGE',
#        'MORTGAGE', 'DEED MISCELLANEOUS', 'AFFIDAVIT OF STREET OPENING',
#        'DEED', 'CERTIFICATE OF STOCK TRANSFER', 'DEED OF CONDEMNATION',
#        'DEED SHERIFF', 'AMENDMENT TO CONDOMINIUM',
#        'DEED MISCELLANEOUS TAXABLE', 'DECLARATION OF CONDOMINIUM',
#        'DEED LAND BANK'], dtype=object)

# %%
deeds = phil.loc[phil['document_type'] == "DEED"]

# %%
deeds.tail(30)
# Out:
#          adjusted_state_tax_amount  objectid document_type display_date  \
# 3845982                        NaN  11699335          DEED   2019-07-17
# 3845983                3250.000000  11699336          DEED   2019-07-18
# 3845985                        NaN  11699338          DEED   2019-06-14
# 3845997                2110.000000  11699552          DEED   2019-07-29
# 3845998                2500.000000  11699553          DEED   2019-07-18
# 3845999                 300.000000  11699554          DEED   2019-07-25
# 3846002                3250.000000  11699341          DEED   2019-07-26
# 3846003                1250.000000  11699342          DEED   2019-07-07
# 3846005                 900.000000  11699344          DEED   2019-07-18
# 3846006                1800.000000  11699345          DEED   2019-07-16
# 3846007                2300.000000  11699346          DEED   2019-07-23
# 3846009                4590.000000  11699348          DEED   2019-07-17
# ...

# %%
parcel = gpd.read_file("../00_data/RAW/philadelphia/dor_property_parcels/DOR_Parcel.geojson")

# %%
parcel['STATUS'].unique()
# Out:
# array([ 1,  3,  2,  9,  4,  5, -1])

# %%
parcel.head()
# Out:
#    OBJECTID RECSUB     BASEREG      MAPREG PARCEL  RECMAP    STCOD   HOUSE  \
# 0      2001         005N080178  005N080178   0178  005N08  87850.0   624.0
# 1      2002         006N090242  006N090242   0242  006N09  59520.0   934.0
# 2      2003         041S060225  041S060225   0225  041S06  21420.0  2439.0
# 3      2004         009N110233  009N110233   0233  009N11  62760.0  1224.0
# 4      2005         048S200008  048S200008   0008  048S20  43300.0  7800.0
#
#     SUF  UNIT  STEX  STDIR       STNAM        STDES STDESSUF ELEV_FLAG  \
# 0  None  None   NaN  North         3RD   ST, Street     None        No
# 1  None  None   NaN   None  NEW MARKET   ST, Street     None        No
# 2  None  None   NaN  South    CARLISLE   ST, Street     None        No
# 3  None  None   NaN   None   PALETHORP   ST, Street     None        No
# 4  None  None   NaN   None    HOLSTEIN  AVE, Avenue     None        No
#
#    TOPELEV  BOTELEV CONDOFLAG                              MATCHFLAG  \
# ...
